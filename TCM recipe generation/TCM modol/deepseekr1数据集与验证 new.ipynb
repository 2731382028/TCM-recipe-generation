# %% [markdown]
# ## Setting up

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None
load_in_4bit = True
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %% [markdown]
# ## Loading the model and tokenizer

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "/root/autodl-tmp/DeepSeek-R1-Medical-保健品数据库7000主料辅料-test", 
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2025.3.14: Fast Llama patching. Transformers: 4.48.2.
#    \\   /|    NVIDIA vGPU-32GB. Num GPUs = 1. Max memory: 31.503 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.9. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Unsloth 2025.3.14 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
prompt_style = """Below is an instruction that describes a task, paired with an input that provides further context.
Write a response that appropriately completes the request.
Before answering, think carefully about the question and create a step-by-step chain of thoughts to ensure a logical and accurate response.

### Instruction:
您是一位医学专家，在诊断和草药方面拥有丰富的知识。给出的配方通常是 3 到 5 种不重复的主料和辅料的组合。
### Question:
{}

### Response:

{}"""

# %% [markdown]
# ## Model inference after fine-tuning

# %%
question = "如何实现改善化学性肝损伤？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：枸杞子(主料)、黄芪(主料)、淫羊藿(主料)、天麻(主料)<｜end▁of▁sentence｜>

# %%
question = "如何实现改善缺铁性贫血？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：枸杞子(主料)、红花(主料)、当归(主料)、菟丝子(主料)、牡蛎(主料)、牡蛎(主料)<｜end▁of▁sentence｜>

# %%
question = "如何实现减肥？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：葛根(主料)、山楂(主料)、大枣(主料)<｜end▁of▁sentence｜>

# %%
question = "如何实现有助于提高免疫力？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：白术(主料)、枸杞子(主料)、当归(主料)、泽泻(主料)、黄芪(主料)、黄芪(主料)<｜end▁of▁sentence｜>

# %%
question = "如何实现改善皮肤水份？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：芦荟(主料)、海藻(主料)、桑叶(主料)、枸杞子(主料)、枳椇子(主料)<｜end▁of▁sentence｜>

# %%
question = "如何实现改善睡眠？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：酸枣仁(主料)、栀子(主料)、酸枣仁(主料)<｜end▁of▁sentence｜>

# %%
question = "如何实现辅助降血糖？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：甘草(主料)、淀粉(主料)、淀粉(主料)、大豆(主料)、大豆(主料)<｜end▁of▁sentence｜>

# %%
question = "如何实现缓解体力疲劳？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：牛磺酸(主料)、维生素B1(辅料)、维生素B2(辅料)、维生素B6(辅料)<｜end▁of▁sentence｜>

# %%
question = "如何实现缓解视疲劳"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：菊花(主料)、茯苓(主料)、枸杞子(主料)、当归(主料)、淫羊藿(主料)、淫羊藿(主料)<｜end▁of▁sentence｜>

# %%
question = "如何实现耐缺氧的功能？"

inputs = tokenizer([prompt_style.format(question, "")], return_tensors="pt").to("cuda")

outputs = model.generate(
    input_ids=inputs.input_ids,
    attention_mask=inputs.attention_mask,
    max_new_tokens=1200,
    use_cache=True,
)
response = tokenizer.batch_decode(outputs)
print(response[0].split("### Response:")[1])
# Out:
# 药方：山药(主料)、枸杞子(主料)、泽泻(主料)、当归(主料)、五味子(主料)、五味子(主料)<｜end▁of▁sentence｜>
